# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
heart=pd.read_csv("heart.csv")

# %%
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
sns.displot(heart['Age'],kde=True)
# Out:
# C:\Users\visha\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(heart['Age'],bins=30)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_7248\4286248114.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart['Age'],bins=30)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Categorical data by pie chart

# %%
heart['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
heart['FastingBS'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
heart.groupby('ChestPainType').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
heart.groupby('RestingECG').size().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: >

# %%
heart.groupby('HeartDisease').size().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: >
